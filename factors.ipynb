# %% [markdown]
# #### **LOB Factors**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from datetime import datetime
import glob 
from pathlib import Path
import csv

plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['figure.figsize'] = (8,5) 

# %config InlineBackend.figure_format = 'svg'

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')  

# from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"

from IPython.display import display
pd.set_option('expand_frame_repr', False)
pd.set_option('display.unicode.ambiguous_as_wide', True)
pd.set_option('display.unicode.east_asian_width', True)
pd.set_option('display.width', 180)


parquet_dir = Path("/Users/roddy/ORIE5640P2/lob_preprocessed_parquet")
files = sorted(glob.glob(str(parquet_dir/"part.*.parquet")))


dfs = []
for f in files:
    print("Loading", f)
    df = pd.read_parquet(f)
    dfs.append(df)
lob_pre = pd.concat(dfs, ignore_index=True)
print("Combined shape:", lob_pre.shape)


lob_pre["time_of_day_s"] = (
    lob_pre["timestamp"].dt.hour   * 3600
  + lob_pre["timestamp"].dt.minute *   60
  + lob_pre["timestamp"].dt.second
)

lob_pre["time_str"] = lob_pre["timestamp"].dt.strftime("%H:%M:%S")
# Out:
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.0.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.1.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.10.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.11.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.12.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.13.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.14.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.15.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.16.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.17.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.18.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.19.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.2.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.20.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.21.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.22.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.23.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.24.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.25.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.26.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.27.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.28.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.29.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.3.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.30.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.31.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.32.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.33.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.34.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.35.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.36.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.37.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.38.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.39.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.4.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.40.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.41.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.42.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.43.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.44.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.45.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.46.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.47.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.48.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.49.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.5.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.50.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.51.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.52.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.53.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.54.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.55.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.56.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.57.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.58.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.59.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.6.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.60.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.61.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.62.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.63.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.64.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.65.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.66.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.67.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.68.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.69.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.7.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.70.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.71.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.72.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.73.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.74.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.75.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.76.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.77.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.78.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.79.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.8.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.80.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.81.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.82.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.83.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.84.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.85.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.86.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.87.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.88.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.89.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.9.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.90.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.91.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.92.parquet
# Loading /Users/roddy/ORIE5640P2/lob_preprocessed_parquet/part.93.parquet
# Combined shape: (85174500, 6)

# %%
lob_pre
# Out:
#                        timestamp    Price  Quantity BidOrAsk  OrderbookPosition  QuantityDifference  time_of_day_s  time_str
# 0        2024-12-28 00:00:00.425  94256.8     0.001      Ask                  0               1.748              0  00:00:00
# 1        2024-12-28 00:00:00.924  94251.1     0.810      Ask                  0              -0.799              0  00:00:00
# 2        2024-12-28 00:00:01.424  94251.1     0.713      Ask                  0              -0.712              1  00:00:01
# 3        2024-12-28 00:00:01.924  94251.1     0.864      Ask                  0              -0.863              1  00:00:01
# 4        2024-12-28 00:00:02.424  94251.1     0.864      Ask                  0              -0.863              2  00:00:02
# ...                          ...      ...       ...      ...                ...                 ...            ...       ...
# 85174495 2024-12-02 23:59:57.524  95881.6     0.001      Bid                  9              -0.049          86397  23:59:57
# 85174496 2024-12-02 23:59:57.924  95881.6     0.001      Bid                  9              -0.049          86397  23:59:57
# 85174497 2024-12-02 23:59:58.464  95881.6     0.001      Bid                  9              -0.049          86398  23:59:58
# 85174498 2024-12-02 23:59:59.084  95881.6     0.001      Bid                  9              -0.049          86399  23:59:59
# 85174499 2024-12-02 23:59:59.604  95881.6     0.001      Bid                  9              -0.087          86399  23:59:59
#
# [85174500 rows x 8 columns]

# %%
qty_wide = lob_pre.pivot_table(
    index="timestamp",
    columns=["BidOrAsk","OrderbookPosition"],
    values="Quantity",
    aggfunc="first"   
).fillna(0)


best = pd.DataFrame(index=qty_wide.index)
for side in ["Bid","Ask"]:
    for lvl, w in zip([0,1,2], [0.6,0.3,0.1]):
        best[f"{side}{lvl+1}_qty"] = qty_wide[(side, lvl)]
        

best["WQ_B"] = sum(w*best[f"Bid{i+1}_qty"] for i,w in enumerate([0.6,0.3,0.1]))
best["WQ_A"] = sum(w*best[f"Ask{i+1}_qty"] for i,w in enumerate([0.6,0.3,0.1]))
best["DepthRatio"] = best["WQ_A"] / best["WQ_B"]
best["OBI"]        = (best["WQ_B"] - best["WQ_A"]) / (best["WQ_B"] + best["WQ_A"])

price_wide = lob_pre.pivot_table(
    index="timestamp",
    columns=["BidOrAsk","OrderbookPosition"],
    values="Price",
    aggfunc="first"
).fillna(method="ffill") 

best["Ask0_price"] = price_wide[("Ask",0)]
best["Bid0_price"] = price_wide[("Bid",0)]
best["spread"]     = best["Ask0_price"] - best["Bid0_price"]
best["midprice"]   = 0.5*(best["Ask0_price"] + best["Bid0_price"])


# online_normalization
def online_normalize(df, cols, lookback):
    roll_mean = df[cols].rolling(window=lookback, min_periods=1).mean()
    roll_std  = df[cols].rolling(window=lookback, min_periods=1).std().replace(0,1)
    df_norm = (df[cols] - roll_mean) / roll_std
    return df_norm

feature_cols = [
    "Bid1_qty","Bid2_qty","Bid3_qty",
    "Ask1_qty","Ask2_qty","Ask3_qty",
    "DepthRatio","OBI",
    "spread","midprice"
]

L = 300  # window 
best_norm = best.copy()
best_norm[feature_cols] = online_normalize(best, feature_cols, lookback=L)

print(best_norm[feature_cols].head(10).round(3))
print(best_norm[feature_cols].rolling(window=L, min_periods=L).mean().dropna().head())
print(best_norm[feature_cols].rolling(window=L, min_periods=L).std().dropna().head())
# Out:
#                          Bid1_qty  Bid2_qty  Bid3_qty  Ask1_qty  Ask2_qty  Ask3_qty  DepthRatio    OBI  spread  midprice
# timestamp
# 2024-11-27 14:26:09.185       NaN       NaN       NaN       NaN       NaN       NaN         NaN    NaN     NaN       NaN
# 2024-11-27 14:26:09.684     0.707     0.707    -0.707    -0.707    -0.707     0.707      -0.707  0.707  -0.707    -0.707
# 2024-11-27 14:26:10.205     0.655    -1.154    -0.577    -0.902    -0.577     0.381      -0.589  0.673  -0.577    -0.577
# 2024-11-27 14:26:10.704     0.960    -0.845    -0.500     0.813    -0.404    -0.934      -0.507  0.560   0.061    -1.141
# 2024-11-27 14:26:11.204     1.054    -0.715    -0.447    -1.193    -0.365    -0.777      -0.485  0.811   0.056    -0.908
# 2024-11-27 14:26:11.724     0.780    -0.633    -0.408    -0.873     1.057    -0.706      -0.437  0.664  -0.875    -1.052
# 2024-11-27 14:26:12.185     0.701    -0.575    -0.378    -0.771     0.909    -0.615      -0.404  0.599  -0.772    -0.906
# 2024-11-27 14:26:12.724    -1.492    -0.486     0.344     2.249     2.453    -0.589       2.435 -1.678  -0.180    -1.326
# 2024-11-27 14:26:13.224    -1.255    -0.551    -0.425    -0.211    -0.403    -0.212       0.279 -1.292   0.607    -1.882
# 2024-11-27 14:26:13.724    -1.104     2.199    -0.402    -0.201     1.072    -0.529       0.147 -1.111   0.568    -1.519
#                          Bid1_qty  Bid2_qty  Bid3_qty  Ask1_qty  Ask2_qty  Ask3_qty  DepthRatio       OBI    spread  midprice
# timestamp
# 2024-11-27 14:28:41.604 -0.035939  0.096188 -0.010937 -0.010789 -0.174311 -0.123944    0.137084 -0.005579  0.052534 -0.516199
# 2024-11-27 14:28:42.084 -0.030637  0.093020 -0.009638 -0.010558 -0.172757 -0.127397    0.138781 -0.003561  0.055339 -0.511073
# 2024-11-27 14:28:42.624 -0.034504  0.096062 -0.003814 -0.009154 -0.172327 -0.130053    0.140100 -0.005941  0.058432 -0.505898
# 2024-11-27 14:28:43.124 -0.039137  0.098278 -0.001762 -0.008492 -0.169381 -0.124760    0.141241 -0.010824  0.062307 -0.498607
# 2024-11-27 14:28:43.644 -0.044578  0.100060 -0.001349 -0.006010 -0.166572 -0.120001    0.142416 -0.016937  0.066177 -0.492100
#                          Bid1_qty  Bid2_qty  Bid3_qty  Ask1_qty  Ask2_qty  Ask3_qty  DepthRatio       OBI    spread  midprice
# timestamp
# 2024-11-27 14:28:41.604  1.013067  1.186252  1.059277  1.021265  0.795734  0.735527    1.303926  1.021750  1.072217  1.415798
# 2024-11-27 14:28:42.084  1.021098  1.185884  1.058660  1.021115  0.795145  0.734043    1.303155  1.023758  1.071324  1.417886
# 2024-11-27 14:28:42.624  1.020690  1.183842  1.060331  1.020175  0.794961  0.733637    1.302616  1.023009  1.070830  1.420474
# 2024-11-27 14:28:43.124  1.019314  1.182697  1.059963  1.020774  0.795737  0.733547    1.302197  1.023793  1.072940  1.422816
# 2024-11-27 14:28:43.644  1.017815  1.181869  1.059813  1.018787  0.796530  0.733932    1.301789  1.024344  1.075008  1.425400

# %%
best_norm
# Out:
#                          Bid1_qty  Bid2_qty  Bid3_qty  Ask1_qty  Ask2_qty  Ask3_qty    WQ_B    WQ_A  DepthRatio       OBI  Ask0_price  Bid0_price    spread  midprice
# timestamp
# 2024-11-27 14:26:09.185       NaN       NaN       NaN       NaN       NaN       NaN  0.0726  0.7217         NaN       NaN     94525.3     94510.6       NaN       NaN
# 2024-11-27 14:26:09.684  0.707107  0.707107 -0.707107 -0.707107 -0.707107  0.707107  2.2054  0.6844   -0.707107  0.707107     94512.2     94508.0 -0.707107 -0.707107
# 2024-11-27 14:26:10.205  0.654711 -1.154449 -0.577350 -0.901667 -0.577350  0.381299  2.3992  0.4407   -0.588627  0.673276     94512.2     94508.0 -0.577350 -0.577350
# 2024-11-27 14:26:10.704  0.960083 -0.844652 -0.500000  0.813274 -0.403847 -0.933895  3.3193  0.6401   -0.507401  0.560313     94508.1     94500.0  0.060560 -1.140673
# 2024-11-27 14:26:11.204  1.054074 -0.715184 -0.447214 -1.193039 -0.365201 -0.777053  3.9457  0.0281   -0.485153  0.811100     94508.1     94500.0  0.055915 -0.907907
# ...                           ...       ...       ...       ...       ...       ...     ...     ...         ...       ...         ...         ...       ...       ...
# 2025-01-02 23:59:57.804 -0.284899  0.238093 -0.445291 -1.179328 -0.288414 -0.205605  0.0497  0.0090   -0.687406  1.753243     96961.2     96951.2  1.945732  2.254213
# 2025-01-02 23:59:58.324 -0.262386 -0.040339 -0.231067 -1.179302 -0.288130 -0.205550  0.0511  0.0090   -0.687406  1.751846     96961.2     96952.0  1.528174  2.309058
# 2025-01-02 23:59:58.804 -0.262800 -0.311024 -0.334743 -1.185094 -0.299145 -0.209001  0.0354  0.0040   -0.687796  1.876015     96962.2     96952.0  2.021643  2.380279
# 2025-01-02 23:59:59.324 -0.192360 -0.032660 -0.346241 -1.185021 -0.298820 -0.208934  0.0659  0.0040   -0.688112  1.985794     96962.2     96954.4  0.802981  2.571506
# 2025-01-02 23:59:59.824 -0.193014 -0.032682 -0.457851 -1.184947 -0.298494 -0.208867  0.0619  0.0040   -0.688048  1.959860     96962.2     96954.4  0.802177  2.549349
#
# [4237032 rows x 14 columns]

# %%
best_norm.to_parquet("best_norm.parquet", compression="snappy")
print("Saved best_fill.parquet")
# Out:
# Saved best_fill.parquet

# %%
nan_counts = best_norm.isna().sum()
print("NaN per column:\n", nan_counts[nan_counts>0])

best_fill = best_norm.copy()
best_fill = best_fill.ffill()   
best_fill = best_fill.bfill()   

print("Remaining NaNs:", best_fill.isna().sum().sum())
# Out:
# NaN per column:
#  Bid1_qty      1
# Bid2_qty      1
# Bid3_qty      1
# Ask1_qty      1
# Ask2_qty      1
# Ask3_qty      1
# DepthRatio    1
# OBI           1
# spread        1
# midprice      1
# dtype: int64
# Remaining NaNs: 0
